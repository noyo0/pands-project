# %% [markdown]
# ### Practice Exploratory data analytics
# - concept: https://purnasaigudikandula.medium.com/exploratory-data-analysis-beginner-univariate-bivariate-and-multivariate-habberman-dataset-2365264b751
#  - **https://www.analyticsvidhya.com/blog/2021/04/exploratory-analysis-using-univariate-bivariate-and-multivariate-analysis-techniques/#:~:text=Some%20patterns%20that%20can%20be,range)%2C%20and%20Standard%20deviation.**
# - tutorial:  https://www.youtube.com/watch?v=6BagRiSY1ds&list=PLMAyPTgGwv2DUV6DZib9eMetsTTX87JNr&index=2

# %% [markdown]
# import iris dataset into data from SOURCEDATA
# + adding headers
# + combine with pandas dataframe

# %%
import pandas as pd
SOURCEDATA="iris.data"
#----read in with giving headers to each column-----------------------
headers=[
    "sepal length (cm)", 
    "sepal width (cm)", 
    "petal length (cm)", 
    "petal width (cm)",
    "species"]
df=pd.read_csv(SOURCEDATA, names=headers)
print(df)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#             species
# ...

# %%
print(df.describe()) # test with pandas describe for quick statistics on data
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
# + import pands

# %%
import pandas as pd # import pandas module
pd.DataFrame(df)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#             species
# ...

# %% [markdown]
# + Describe data

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.054000           3.758667
# std             0.828066          0.433594           1.764420
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.198667
# std            0.763161
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %% [markdown]
#  + Load matplotlib.pyplot module
#  + Distribution with histogram

# %% [markdown]
# + add target column

# %%
df['target']=0
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#        species  target
# 0  Iris-setosa       0
# 1  Iris-setosa       0
# 2  Iris-setosa       0
# 3  Iris-setosa       0
# 4  Iris-setosa       0

# %%
import matplotlib.pyplot as plt
#import matplotlib as plt
col = "sepal width (cm)"
df[col].hist(bins=12)
plt.suptitle(col) #display title
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### relation between data

# %%
import seaborn as sns
ax_x = "sepal length (cm)"
ax_y = "sepal width (cm)"
sns.relplot(x=ax_x, y=ax_y, hue='species', data=df) # sns.relplot = relation plot
plt.suptitle('sepal width and lenght relations within species')
# Out:
# Text(0.5, 0.98, 'sepal width and lenght relations within species')

# %% [markdown]
# ### Univariate plotting
# ##### Univariate analysis explores each variable in a data set, separately. It looks at the range of values, as well as the central tendency of the values. It describes the pattern of response to the variable. It describes each variable on its own. Descriptive statistics describe and summarize data.
#
# ##### Relationship of the data with the target
#
# + using a 'target' column with identical values for each entries per species we can visualise each attribute separately.

# %%
# set target value 0,1,2 for each species ref: https://datagy.io/pandas-conditional-column/
df.loc[df['species']== 'Iris-setosa','target']=0
df.loc[df['species']== 'Iris-versicolor','target']=1
df.loc[df['species']== 'Iris-virginica','target']=2

# %% [markdown]
# #### Show data on scatter plot separated by target values 0,1 and 2

# %%
ax_x = "sepal length (cm)"
ax_y = "target"
sns.relplot(x=ax_x, y=ax_y, hue='species', data=df) # sns.relplot = relation plot
plt.suptitle(f'{ax_x}, comparison',y=1.07)
# Out:
# Text(0.5, 1.07, 'sepal length (cm), comparison')

# %%
ax_x = "sepal width (cm)"
ax_y = "target"
sns.relplot(x=ax_x, y=ax_y, hue='species', data=df) # sns.relplot = relation plot
plt.suptitle(f'{ax_x}, comparison',y=1.07)
# Out:
# Text(0.5, 1.07, 'sepal width (cm), comparison')

# %%
ax_x = "sepal length (cm)"
ax_y = "target"
sns.relplot(x=ax_x, y=ax_y, hue='species', data=df) # sns.relplot = relation plot
plt.suptitle(f'{ax_x}, comparison',y=1.07)
# Out:
# Text(0.5, 1.07, 'sepal length (cm), comparison')

# %%
#it appears we can tell apart the species by petal width and lenght
ax_x = "petal width (cm)"
ax_y = "target"
sns.relplot(x=ax_x, y=ax_y, hue='species', data=df) # sns.relplot = relation plot
plt.suptitle(f'{ax_x}, comparison',y=1.07)
# Out:
# Text(0.5, 1.07, 'petal width (cm), comparison')

# %% [markdown]
# #### Seaborn EDA - Pairplots

# %%
sns.pairplot(df, hue="species")
